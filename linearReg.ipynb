# %%
import numpy as np;
import pandas as pd;
import matplotlib.pyplot as plt;
from sklearn.linear_model import LinearRegression,Ridge,Lasso;
from sklearn.model_selection import train_test_split;

# %%
df = pd.read_csv("exercise1.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
plt.xlabel("year")
plt.ylabel("output")
plt.scatter(df["year"],df.iloc[0:,1],color="yellow",marker="+")

# %%
x =df[["year"]]
y =df.iloc[0:,1]
x_train,x_test,y_train,y_test = train_test_split(x,y)
reg = LinearRegression();
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# 26  1996             16699.826680
# 27  1997             17310.757750
# 28  1998             16622.671870
# 29  1999             17581.024140
# 30  2000             18987.382410
# 31  2001             18601.397240
# 32  2002             19232.175560
# 33  2003             22739.426280
# 34  2004             25719.147150
# 35  2005             29198.055690
# 36  2006             32738.262900
# 37  2007             36144.481220
# 38  2008             37446.486090
# 39  2009             32755.176820
# 40  2010             38420.522890
# 41  2011             42334.711210
# 42  2012             42665.255970
# 43  2013             42676.468370
# 44  2014             41039.893600
# 45  2015             35175.188980
# 46  2016             34229.193630

# %%
reg.fit(x_train,y_train)
df.shape
# Out:
# (47, 2)

# %%
reg.predict(x_test)
# Out:
# array([24600.69308859, 36514.35998291, 16090.93102122,  -928.59311352,
#         7581.16895385,  5879.21654037, 28004.59791554,   -77.61690679,
#          773.35929995,  8432.14516059, 33110.45515597, 21196.78826164])

# %%
reg.coef_
# Out:
# array([850.97620674])

# %%
plt.xlabel("year")
plt.ylabel("output")
plt.scatter(df["year"],df.iloc[0:,1],color="yellow",marker="+")
plt.plot(df["year"],reg.predict(df[["year"]]))

# %%
datadict = {"year" : [i for i in range (2020,2026)]}
df = pd.DataFrame.from_dict(datadict)
df["prices"] = reg.predict(df[["year"]])
df.to_csv("final_output.csv",index=False)

# %%
model2 = Ridge()
model2.fit(x_train,y_train)
# Out:
# Ridge()

# %%
model2.predict(x_test)
# Out:
# array([24599.85654807, 36511.42136622, 16091.59596369,  -924.92520509,
#         7583.3353793 ,  5881.68326242, 28003.16078183,   -74.09914665,
#          776.72691179,  8434.16143774, 33108.11713246, 21196.55231432])

# %%
reg.score(x_train,y_train)
# Out:
# 0.8762674918390797

# %%
reg.score(x_test,y_test)
# Out:
# 0.916441915441665

# %%
model2.score(x_train,y_train)
# Out:
# 0.8762674645591839

# %%
model2.score(x_test,y_test)
# Out:
# 0.9164763325471724

# %%
model3 = Lasso()

# %%
model3.fit(x_train,y_train)
# Out:
# Lasso()

# %%
model3.predict(x_test)
# Out:
# array([24600.65867625, 36514.23909853, 16090.95837462,  -928.44222864,
#         7581.25807299,  5879.31801267, 28004.5387969 ,   -77.47219847,
#          773.49783169,  8432.22810316, 33110.35897788, 21196.7785556 ])

# %%
model3.score(x_train,y_train)
# Out:
# 0.876267491792916

# %%
model3.score(x_test,y_test)
# Out:
# 0.9164433327131765
